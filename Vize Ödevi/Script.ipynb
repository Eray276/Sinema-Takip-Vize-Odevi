-- %% [markdown]
-- # [sinematakip]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [sinematakip]    Script Date: 12.05.2023 21:34:56 ******/
CREATE DATABASE [sinematakip]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'sinematakip', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\sinematakip.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'sinematakip_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\sinematakip_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [sinematakip] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [sinematakip].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [sinematakip] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [sinematakip] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [sinematakip] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [sinematakip] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [sinematakip] SET ARITHABORT OFF 
GO
ALTER DATABASE [sinematakip] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [sinematakip] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [sinematakip] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [sinematakip] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [sinematakip] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [sinematakip] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [sinematakip] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [sinematakip] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [sinematakip] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [sinematakip] SET  DISABLE_BROKER 
GO
ALTER DATABASE [sinematakip] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [sinematakip] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [sinematakip] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [sinematakip] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [sinematakip] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [sinematakip] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [sinematakip] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [sinematakip] SET RECOVERY FULL 
GO
ALTER DATABASE [sinematakip] SET  MULTI_USER 
GO
ALTER DATABASE [sinematakip] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [sinematakip] SET DB_CHAINING OFF 
GO
ALTER DATABASE [sinematakip] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [sinematakip] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [sinematakip] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [sinematakip] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'sinematakip', N'ON'
GO
ALTER DATABASE [sinematakip] SET QUERY_STORE = ON
GO
ALTER DATABASE [sinematakip] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Film]

-- %%
USE [sinematakip]
GO

-- %%
/****** Object:  Table [dbo].[Film]    Script Date: 12.05.2023 21:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Film](
	[Film_Id] [int] IDENTITY(1,1) NOT NULL,
	[Film_Adı] [text] NOT NULL,
	[Seans_Saati] [text] NOT NULL,
	[Salon_Id] [int] NOT NULL,
 CONSTRAINT [PK_Film] PRIMARY KEY CLUSTERED 
(
	[Film_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Müşteri]

-- %%
/****** Object:  Table [dbo].[Müşteri]    Script Date: 12.05.2023 21:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Müşteri](
	[Müşteri_Id] [int] IDENTITY(1,1) NOT NULL,
	[Ad_Soyad] [text] NOT NULL,
	[Bilet_Sayısı] [int] NOT NULL,
	[Bilet_Aralığı] [text] NOT NULL,
	[Film_Id] [int] NOT NULL,
	[Salon_Id] [int] NOT NULL,
 CONSTRAINT [PK_Müşteri] PRIMARY KEY CLUSTERED 
(
	[Müşteri_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Salon]

-- %%
/****** Object:  Table [dbo].[Salon]    Script Date: 12.05.2023 21:34:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Salon](
	[Salon_Id] [int] NOT NULL,
	[Salon_Adı] [text] NOT NULL,
	[Koltuk_Sayısı] [int] NOT NULL,
 CONSTRAINT [PK_Salon] PRIMARY KEY CLUSTERED 
(
	[Salon_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Film]

-- %%
SET IDENTITY_INSERT [dbo].[Film] ON 
INSERT [dbo].[Film] ([Film_Id], [Film_Adı], [Seans_Saati], [Salon_Id]) VALUES (1, N'testere', N'19', 0)
SET IDENTITY_INSERT [dbo].[Film] OFF
GO

-- %% [markdown]
-- # [dbo].[Müşteri]

-- %%
SET IDENTITY_INSERT [dbo].[Müşteri] ON 
INSERT [dbo].[Müşteri] ([Müşteri_Id], [Ad_Soyad], [Bilet_Sayısı], [Bilet_Aralığı], [Film_Id], [Salon_Id]) VALUES (1, N'eray karadeniz', 1, N'1', 1, 0)
SET IDENTITY_INSERT [dbo].[Müşteri] OFF
GO

-- %% [markdown]
-- # [dbo].[Salon]

-- %%
INSERT [dbo].[Salon] ([Salon_Id], [Salon_Adı], [Koltuk_Sayısı]) VALUES (0, N'1', 20)
GO

-- %% [markdown]
-- # [FK_Film_Salon]

-- %%
ALTER TABLE [dbo].[Film]  WITH CHECK ADD  CONSTRAINT [FK_Film_Salon] FOREIGN KEY([Salon_Id])
REFERENCES [dbo].[Salon] ([Salon_Id])
GO
ALTER TABLE [dbo].[Film] CHECK CONSTRAINT [FK_Film_Salon]
GO

-- %% [markdown]
-- # [FK_Müşteri_Film]

-- %%
ALTER TABLE [dbo].[Müşteri]  WITH CHECK ADD  CONSTRAINT [FK_Müşteri_Film] FOREIGN KEY([Film_Id])
REFERENCES [dbo].[Film] ([Film_Id])
GO
ALTER TABLE [dbo].[Müşteri] CHECK CONSTRAINT [FK_Müşteri_Film]
GO

-- %% [markdown]
-- # [FK_Müşteri_Salon]

-- %%
ALTER TABLE [dbo].[Müşteri]  WITH CHECK ADD  CONSTRAINT [FK_Müşteri_Salon] FOREIGN KEY([Salon_Id])
REFERENCES [dbo].[Salon] ([Salon_Id])
GO
ALTER TABLE [dbo].[Müşteri] CHECK CONSTRAINT [FK_Müşteri_Salon]
GO

-- %% [markdown]
-- # [sinematakip]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [sinematakip] SET  READ_WRITE 
GO
